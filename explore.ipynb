# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import wrangle

# %%
df = wrangle.get_flight_data()
df.head()
# Out:
#    Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0  2008      1           3          4   2003.0        1955
# 1           1  2008      1           3          4    754.0         735
# 2           2  2008      1           3          4    628.0         620
# 3           4  2008      1           3          4   1829.0        1755
# 4           5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# 0   2211.0        2225            WN  ...     4.0     8.0          0
# 1   1002.0        1000            WN  ...     5.0    10.0          0
# 2    804.0         750            WN  ...     3.0    17.0          0
# 3   1959.0        1925            WN  ...     3.0    10.0          0
# 4   2121.0        2110            WN  ...     4.0    10.0          0
#
#    CancellationCode  Diverted  CarrierDelay  WeatherDelay NASDelay  \
# 0                 N         0           NaN           NaN      NaN
# 1                 N         0           NaN           NaN      NaN
# 2                 N         0           NaN           NaN      NaN
# 3                 N         0           2.0           0.0      0.0
# 4                 N         0           NaN           NaN      NaN
#
#   SecurityDelay  LateAircraftDelay
# 0           NaN                NaN
# 1           NaN                NaN
# 2           NaN                NaN
# 3           0.0               32.0
# 4           NaN                NaN
#
# [5 rows x 30 columns]

# %%
df = wrangle.prepare_flight_data(df)
df.head()
# Out:
#        Year  Month  DayofMonth  DayOfWeek  CRSDepTime  CRSArrTime  \
# 51640  2008      1           1          2        1429        1922
# 53353  2008      1           4          5        2020        2138
# 53354  2008      1           4          5        1429        1922
# 54134  2008      1           5          6        1429        1922
# 54135  2008      1           5          6        1237        1355
#
#       UniqueCarrier TailNum  CRSElapsedTime  AirTime  ...  DepDelay  Origin  \
# 51640            OO  N772SK             173      153  ...         7     LAX
# 53353            OO  N767SK             198      195  ...        62     DFW
# 53354            OO  N767SK             173      146  ...        21     LAX
# 54134            OO  N768SK             173      143  ...        19     LAX
# 54135            OO  N768SK             198      177  ...        11     DFW
#
#       Dest Distance  CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  \
# 51640  DFW     1235            15             0         0              0
# 53353  LAX     1235             0             0         0              0
# 53354  DFW     1235            22             0         0              0
# 54134  DFW     1235             0             0         0              0
# 54135  LAX     1235            24             0         0              0
#
#        LateAircraftDelay  Delayed_Status
# 51640                  0               1
# 53353                 98               2
# 53354                  0               1
# 54134                 20               1
# 54135                  0               1
#
# [5 rows x 21 columns]

# %%
df.UniqueCarrier.value_counts()
# Out:
# AA    6162
# DL    3541
# UA    2403
# WN     510
# OO     230
# Name: UniqueCarrier, dtype: int64
